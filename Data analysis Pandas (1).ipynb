# %%
import pandas as pd
import numpy as np

# %%
pd.Series([2,4,6, "hi", "hello"])
# Out:
# 0        2
# 1        4
# 2        6
# 3       hi
# 4    hello
# dtype: object

# %%
pd.Series([2,7,5], index = ['a','b','c'])
# Out:
# a    2
# b    7
# c    5
# dtype: int64

# %%
s1 = pd.Series([3,5,7], index = ['a', 'b','c'])
s2 = pd.Series([5,7,9], index = ['a','b','f'])

# %%
s1
# Out:
# a    3
# b    5
# c    7
# dtype: int64

# %%
s2
# Out:
# a    5
# b    7
# f    9
# dtype: int64

# %%
s1 * s2
# Out:
# a    15.0
# b    35.0
# c     NaN
# f     NaN
# dtype: float64

# %%
s1 - s2
# Out:
# a   -2.0
# b   -2.0
# c    NaN
# f    NaN
# dtype: float64

# %%
s1 + s2
# Out:
# a     8.0
# b    12.0
# c     NaN
# f     NaN
# dtype: float64

# %%
df = pd.DataFrame(data=[[2,4,6,-1],[3,-4,2,-1],[-10,3,5,-7]],
                  columns=['c1','c2','c3','c4'],index=['r1','r2','r3'])
df
# Out:
#     c1  c2  c3  c4
# r1   2   4   6  -1
# r2   3  -4   2  -1
# r3 -10   3   5  -7

# %%
import pandas as pd
df
# Out:
#     c1  c2  c3  c4
# r1   2   4   6  -1
# r2   3  -4   2  -1
# r3 -10   3   5  -7

# %%
df.head()
# Out:
#     c1  c2  c3  c4
# r1   2   4   6  -1
# r2   3  -4   2  -1
# r3 -10   3   5  -7

# %%
df.head(2)
# Out:
#     c1  c2  c3  c4
# r1   2   4   6  -1
# r2   3  -4   2  -1

# %%
df["new"]=[7,5,8]

# %%
df
# Out:
#     c1  c2  c3  c4  new
# r1   2   4   6  -1    7
# r2   3  -4   2  -1    5
# r3 -10   3   5  -7    8

# %%
df.head()
# Out:
#     c1  c2  c3  c4  new
# r1   2   4   6  -1    7
# r2   3  -4   2  -1    5
# r3 -10   3   5  -7    8

# %% [markdown]
# # Handling missing data

# %%
df1 = pd.DataFrame([[np.nan, 3, 5, np.nan], [np.nan, 4, np.nan, 0], [np.nan, 5, 8, 0]], columns = list('ABCD'))

# %%
df1
# Out:
#     A  B    C    D
# 0 NaN  3  5.0  NaN
# 1 NaN  4  NaN  0.0
# 2 NaN  5  8.0  0.0

# %%
df1.dropna(axis=1)
# Out:
#    B
# 0  3
# 1  4
# 2  5

# %%
df1.dropna(axis=1, how='all')
# Out:
#    B    C    D
# 0  3  5.0  NaN
# 1  4  NaN  0.0
# 2  5  8.0  0.0

# %%
df1.dropna(axis=1,how='any')
# Out:
#    B
# 0  3
# 1  4
# 2  5

# %%
df1.dropna(axis=0, how='all')
# Out:
#     A  B    C    D
# 0 NaN  3  5.0  NaN
# 1 NaN  4  NaN  0.0
# 2 NaN  5  8.0  0.0

# %%
df1.dropna(axis=0,how='any')
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df2=pd.DataFrame([[np.nan, 3, 5, np.nan], [np.nan, 4, np.nan, 0], [np.nan, 5, 8, 0]], columns = list('abcd'))

# %%
df2
# Out:
#     a  b    c    d
# 0 NaN  3  5.0  NaN
# 1 NaN  4  NaN  0.0
# 2 NaN  5  8.0  0.0

# %%
r=df2['c'].fillna('o')

# %%
r
# Out:
# 0    5
# 1    o
# 2    8
# Name: c, dtype: object

# %%
df2['b'].mean()
# Out:
# 4.0

# %%
df2['c'].mean()
# Out:
# 6.5

# %%
m=df2['c'].fillna(df2['c'].mean())

# %%
m
# Out:
# 0    5.0
# 1    6.5
# 2    8.0
# Name: c, dtype: float64

# %%
q=df2.replace(0.0, 'There was zero')

# %%
q
# Out:
#     a  b    c               d
# 0 NaN  3  5.0             NaN
# 1 NaN  4  NaN  There was zero
# 2 NaN  5  8.0  There was zero

# %%
t=df2.replace(np.nan,'There was missing value')

# %%
t
# Out:
#                          a  b                        c  \
# 0  There was missing value  3                        5
# 1  There was missing value  4  There was missing value
# 2  There was missing value  5                        8
#
#                          d
# 0  There was missing value
# 1                        0
# 2                        0

# %% [markdown]
# # READ WRITE FILES

# %%
import numpy as np
import pandas as pd

# %%
df3=pd.DataFrame(data=[[2,3,5],['hi','hello','python'],[34,True, False]], index= ['R1','R2','R3'])

# %%
df3
# Out:
#      0      1       2
# R1   2      3       5
# R2  hi  hello  python
# R3  34   True   False

# %%
df3.to_csv('samplcsv.csv')

# %%
dfn1= pd.read_csv('D:\DATA SCIENCE\data set/auto.csv')

# %%
dfn1
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
auto_data= pd.read_csv('D:\DATA SCIENCE\data set/auto.csv')

# %%
auto_data
# Out:
#            Make                             Model    Type  Origin DriveTrain  \
# 0         Acura                               MDX     SUV    Asia        All
# 1         Acura                    RSX Type S 2dr   Sedan    Asia      Front
# 2         Acura                           TSX 4dr   Sedan    Asia      Front
# 3         Acura                            TL 4dr   Sedan    Asia      Front
# 4         Acura                        3.5 RL 4dr   Sedan    Asia      Front
# 5         Acura           3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6         Acura            NSX coupe 2dr manual S  Sports    Asia       Rear
# 7          Audi                       A4 1.8T 4dr   Sedan  Europe      Front
# 8          Audi            A41.8T convertible 2dr   Sedan  Europe      Front
# 9          Audi                        A4 3.0 4dr   Sedan  Europe      Front
# 10         Audi         A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# ...

# %%
dfn2=pd.read_excel('D:\DATA SCIENCE\data set/Admit.xls')

# %%
dfn2
# Out:
#        Name  Age Gender  Height        SSN  Balance  emp_id
# 0    Alfred   14      M    69.0  547585853     1000      11
# 1     Alice   13      F    56.5  547585855     2000      12
# 2   Barbara   13      F    65.3  547585867     3000      13
# 3     Carol   14      F    62.8  547585852     4000      14
# 4     Henry   14      M    63.5  547585859     5000      15
# 5     James   12      M    57.3  547585854     6000      16
# 6      Jane   12      F    59.8  547585851     7000      17
# 7     Janet   15      F    62.5  547585850     8000      18
# 8   Jeffrey   13      M    62.5  547585858     9000      19
# 9      John   12      M    59.0  547358585    10000      20
# 10    Joyce   11      F    51.3  547548585    11000      21
# 11     Judy   14      F    64.3  547578585    12000      22
# 12   Louise   12      F    56.3  547588585    13000      23
# 13     Mary   15      F    66.5  454758585    14000      24
# 14   Philip   16      M    72.0  545758585    15000      25
# ...

# %%
dfn2['Name'].value_counts()
# Out:
# Judy       1
# William    1
# Jeffrey    1
# Alice      1
# John       1
# Barbara    1
# Joyce      1
# Carol      1
# Ronald     1
# Philip     1
# Alfred     1
# Thomas     1
# Louise     1
# Jane       1
# James      1
# Janet      1
# Robert     1
# Mary       1
# Henry      1
# Name: Name, dtype: int64

# %%
dfn2['Gender'].value_counts()
# Out:
# M    10
# F     9
# Name: Gender, dtype: int64

# %%
dfn2['Height'].value_counts()
# Out:
# 62.5    2
# 66.5    2
# 51.3    1
# 56.3    1
# 56.5    1
# 63.5    1
# 59.0    1
# 72.0    1
# 67.0    1
# 59.8    1
# 57.5    1
# 65.3    1
# 64.3    1
# 64.8    1
# 62.8    1
# 57.3    1
# 69.0    1
# Name: Height, dtype: int64

# %%
dfn2['Gender'].value_counts()
# Out:
# M    10
# F     9
# Name: Gender, dtype: int64

# %%
byteam = dfn2.groupby('Gender')

# %%
byteam

# %%
byteam.sum()
# Out:
#         Age  Height         SSN  Balance  emp_id
# Gender
# F       119   545.3  4835403615    74000     164
# M       134   639.1  5874244944   116000     216

# %%
byteam.mean()
# Out:
#               Age     Height           SSN       Balance     emp_id
# Gender
# F       13.222222  60.588889  5.372671e+08   8222.222222  18.222222
# M       13.400000  63.910000  5.874245e+08  11600.000000  21.600000

# %%
byname = dfn2.groupby('Name')

# %%
byname

# %%
byname.sum()
# Out:
#          Age  Height        SSN  Balance  emp_id
# Name
# Alfred    14    69.0  547585853     1000      11
# Alice     13    56.5  547585855     2000      12
# Barbara   13    65.3  547585867     3000      13
# Carol     14    62.8  547585852     4000      14
# Henry     14    63.5  547585859     5000      15
# James     12    57.3  547585854     6000      16
# Jane      12    59.8  547585851     7000      17
# Janet     15    62.5  547585850     8000      18
# Jeffrey   13    62.5  547585858     9000      19
# John      12    59.0  547358585    10000      20
# Joyce     11    51.3  547548585    11000      21
# Judy      14    64.3  547578585    12000      22
# Louise    12    56.3  547588585    13000      23
# Mary      15    66.5  454758585    14000      24
# Philip    16    72.0  545758585    15000      25
# Robert    12    64.8  547508595    16000      26
# Ronald    15    67.0  540758585    17000      27
# Thomas    11    57.5  547758585    18000      28
# ...

# %%
byname.mean()
# Out:
#          Age  Height        SSN  Balance  emp_id
# Name
# Alfred    14    69.0  547585853     1000      11
# Alice     13    56.5  547585855     2000      12
# Barbara   13    65.3  547585867     3000      13
# Carol     14    62.8  547585852     4000      14
# Henry     14    63.5  547585859     5000      15
# James     12    57.3  547585854     6000      16
# Jane      12    59.8  547585851     7000      17
# Janet     15    62.5  547585850     8000      18
# Jeffrey   13    62.5  547585858     9000      19
# John      12    59.0  547358585    10000      20
# Joyce     11    51.3  547548585    11000      21
# Judy      14    64.3  547578585    12000      22
# Louise    12    56.3  547588585    13000      23
# Mary      15    66.5  454758585    14000      24
# Philip    16    72.0  545758585    15000      25
# Robert    12    64.8  547508595    16000      26
# Ronald    15    67.0  540758585    17000      27
# Thomas    11    57.5  547758585    18000      28
# ...

# %%
dfn
# Out:
#      0      1       2
# R1   2      3       5
# R2  hi  hello  python
# R3  34   True   False

# %%
df3.to_excel('sample1.xls')

# %%
dfm=pd.read_excel('sample1.xls')

# %%
dfm
# Out:
#      0      1       2
# R1   2      3       5
# R2  hi  hello  python
# R3  34   True   False

# %%
import pandas as pd
r=pd.read_html('https://en.wikipedia.org/wiki/The_World%27s_Billionaires')

# %%
r
# Out:
# [                                                    0  \
#  0   List of the world's billionaires, ranked in or...
#  1                                                 NaN
#  2   The net worth of the world's billionaires incr...
#  3                                 Publication details
#  4                                           Publisher
#  5                                         Publication
#  6                                     First published
#  7                                  Latest publication
#  8                      Current list details (2018)[2]
#  9                                          Wealthiest
#  10                                    Net worth (1st)
#  11                             Number of billionaires
#  12                         Total list net worth value
#  13                                  Average net worth
#  14                                    Number of women
#  15             Number of people aged 40 years or less
# ...

# %%
dfn
# Out:
#      0      1       2
# R1   2      3       5
# R2  hi  hello  python
# R3  34   True   False

# %%
s=pd.read_html('https://en.wikipedia.org/wiki/List_of_Americans_by_net_worth')

# %%
s
# Out:
# [       0                  1                2    3  \
#  0   Rank               Name  Net worth (USD)  Age
#  1    NaN         Jeff Bezos     $112 billion   54
#  2    NaN         Bill Gates      $90 billion   62
#  3    NaN    Mark Zuckerberg      $71 billion   34
#  4    NaN     Warren Buffett      $62 billion   87
#  5    NaN      David H. Koch      $60 billion   77
#  6    NaN       Charles Koch      $60 billion   82
#  7    NaN      Larry Ellison    $58.8 billion   73
#  8    NaN  Michael Bloomberg      $50 billion   76
#  9    NaN         Larry Page    $48.8 billion   44
#  10   NaN        Sergey Brin    $47.5 billion   44
#  11   NaN         Jim Walton    $46.4 billion   69
#  12   NaN   S. Robson Walton    $46.2 billion   73
#  13   NaN       Alice Walton      $46 billion   68
#  14   NaN    Sheldon Adelson    $38.5 billion   84
#  15   NaN      Steve Ballmer    $38.4 billion   61
#
#                                    4                                   5
# ...

# %%
import pandas as pd
list_tables=pd.read_html("https://en.wikipedia.org/wiki/Forbes_list_of_Indian_billionaires")

# %%
list_tables
# Out:
# [    0                                                  1
#  0 NaN  This article needs to be updated. Please updat...,
#          0                    1                                 2            3  \
#  0   India                World                              Name          Age
#  1      01                   19                     Mukesh Ambani           61
#  2      02                   58                       Azim Premji           73
#  3      03                   62                    Lakshmi Mittal           68
#  4      04                   98                        Shiv Nadar           73
#  5      05                  115                    Dilip Shanghvi           63
#  6      06                  127                       Kumar Birla           51
#  7      07                  143                        Uday Kotak           59
#  8      08                  151                Radhakishan Damani           63
# ...

# %%
len(list_tables)
# Out:
# 4

# %%
list_tables[2]
# Out:
#                           0  \
# 0  vteForbes magazine lists
# 1                 Companies
# 2                    People
# 3                   General
# 4                   Richest
# 5                    Places
# 6                    Sports
# 7                Technology
# 8                   General
# 9                   Richest
#
#                                                    1        2  \
# 0                                                NaN      NaN
# 1                             Global 2000 Forbes 500      NaN
# 2  General Celebrity 100 30 Under 30 China Celebr...  General
# 3  Celebrity 100 30 Under 30 China Celebrity 100 ...      NaN
# 4  The World's Billionaires Forbes 400 Forbes Asi...      NaN
# 5                            America's Best Colleges      NaN
# 6  Highest-paid athletes Most valuable sports tea...      NaN
# 7                Midas List (Tech's Top Deal Makers)      NaN
# 8  Celebrity 100 30 Under 30 China Celebrity 100 ...      NaN
# ...

# %%
nl=list_tables[1]

# %%
nl
# Out:
#         0                                 1                     2  \
# 0   India                             World                  Name
# 1      01                                36         Mukesh Ambani
# 2      02                                44        Dilip Shanghvi
# 3      03                                55           Azim Premji
# 4      04                                88            Shiv Nadar
# 5      05                               135        Lakshmi Mittal
# 6      06                               184            Uday Kotak
# 7      07                               196           Kumar Birla
# 8      08                               219          Sunil Mittal
# 9      09                               233     Desh Bandhu Gupta
# 10     10                               270    Shashi & Ravi Ruia
# 11     69                               NaN                   NaN
# 12     12                               338        Micky Jagtiani
# ...

# %% [markdown]
# # DATA VISUALIZATION WITH PANDAS

# %%
dv = pd.DataFrame(data=[[2,4,26,1],[3,4,9,1],[-10,3,15,-7]],
                  columns=['c1','c2','c3','c4'],
                  index=['r1','r2','r3'])

# %%
dv
# Out:
#     c1  c2  c3  c4
# r1   2   4  26   1
# r2   3   4   9   1
# r3 -10   3  15  -7

# %%
# %matplotlib inline

# %%
dv['c3'].plot.area()

# %%
dv['c2'].plot.bar()

# %%
dv.plot.bar()

# %%
dv.plot.barh()

# %%
dv.plot.line()

# %%
dv.plot.box()

# %%
dv.plot.scatter(x="c1",y="c4")

# %%
ab = lambda a,b:a+b
