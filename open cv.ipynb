# %%
import cv2
import imutils
print(cv2.__version__)
# Out:
# 4.5.5

# %%
img = cv2.imread("img")
x,y= img.shape[:2]
print("height={}, width={}".format(x,y))
# Out:
# height=499, width=720

# %%
from PIL import Image
img= Image.open("img")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x499 at 0x1B76AEC20A0>

# %%
new_size= cv2.resize(img,(1020,1080))
cv2.imwrite("x.jpg",img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-67d93a62b931> in <module>
# ----> 1 new_size= cv2.resize(img,(1020,1080))
#       2 cv2.imwrite("x.jpg",img)
#
# error: OpenCV(4.5.5) :-1: error: (-5:Bad argument) in function 'resize'
# > Overload resolution failed:
# >  - src is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'src'
